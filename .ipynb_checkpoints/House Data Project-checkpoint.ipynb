# %%
###import packages###
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, MaxNLocator #formating number in charts
from scipy.stats import trim_mean
import os #to load csv to folder
import seaborn as sns
from IPython.display import display, HTML #for format
###removing scientific notation###
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
###Connection info for GitHub File###
url = 'https://github.com/TexasTori/ADS500B/raw/23fed13154371851d00cb375e177636726bf8bc2/house_sales.csv'
df_orig = pd.read_csv(url, sep=',')

###set up to automate files print location for team###
cwd = os.getcwd() 
log_prefix = os.path.join(cwd,'log_files')
print(log_prefix)
# Out:
# C:\Users\Widjaja\ADS500B\log_files

# %%
###Uncomment below for testing:###

#df_orig.head()
#df_orig.to_csv(os.path.join(log_prefix, "testpywrite.csv"), index=False)

# %% [markdown]
# In order to write data to a csv/txt file on your laptop, use the os.path.join()
# ###### Example:
# df_test is the data you want to print to csv
# ###### Python:
# df_orig.to_csv(os.path.join(log_prefix, "testpywrite.csv"), index=False)
#
# Copy and paste the above code and update the data frame name at the beginning and the text between the " " which will name your file.

# %%
###view file sample###
df_orig.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00       1180.0
# 1  6414100192  20141209T000000  538000.0       3.0       2.25       2570.0
# 2  5631500400  20150225T000000  180000.0       2.0       1.00        770.0
# 3  2487200875  20141209T000000  604000.0       4.0       3.00       1960.0
# 4  1954400510  20150218T000000  510000.0       3.0       2.00       1680.0
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...      7        1180              0
# 1    7242.0     2.0           0     0  ...      7        2170            400
# 2   10000.0     1.0           0     0  ...      6         770              0
# 3    5000.0     1.0           0     0  ...      7        1050            910
# 4    8080.0     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
###Printing out the rows and columns of the dataset to highlight the dimensions###
print("Dimensions", df_orig.shape)
# Out:
# Dimensions (21613, 21)

# %%
###The datatypes of each column are found using dtypes()###
display(HTML("<u>Data Types:</u>"))
print(df_orig.dtypes)
# Out:
# <u>Data Types:</u>
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                float64
# bathrooms               float64
# sqft_living             float64
# sqft_lot                float64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# ## The filetype is csv and the import method was through Pandas

# %%
###Null values count###
null_data = df_orig.isnull().sum()
display(HTML("<u>Null Data Counts:</u>"))
print(null_data)
# Out:
# <u>Null Data Counts:</u>
# id                   0
# date             21613
# price                0
# bedrooms          1134
# bathrooms         1068
# sqft_living       1110
# sqft_lot          1044
# floors               0
# waterfront           0
# view                 0
# condition            0
# grade                0
# sqft_above           0
# sqft_basement        0
# yr_built             0
# yr_renovated         0
# zipcode              0
# lat                  0
# long                 0
# sqft_living15        0
# sqft_lot15           0
# dtype: int64

# %%
display(HTML("<u>Price Details:</u>"))
df_orig['price'].describe().apply(lambda x: format(round(x,2), '.2f'))
# Out:
# <u>Price Details:</u>
# count      21613.00
# mean      540088.14
# std       367127.20
# min        75000.00
# 25%       321950.00
# 50%       450000.00
# 75%       645000.00
# max      7700000.00
# Name: price, dtype: object

# %%
plt.hist(df_orig['price'], bins = 55)
plt.show()

###add title and axis -----------------------------------------------------------------------------------------

# %%
fig, ax = plt.subplots(figsize=(10, 3))
ax.boxplot(df_orig['price'], vert=False)
ax.ticklabel_format(style='plain', axis='x')

###print out###
plt.show()
###add title and axis --------------------------------------------------------------------------------------

# %% [markdown]
# ## Clean, Wrangle and Handle Missing Data Step

# %%
# BOBBY

###Taking the current date format with TXXXXX and turning it into a normal date format of YYYY MM DD###
df_orig['date'] = pd.to_datetime(df_orig['date'], format='%Y%m%dT%H%M%S', errors='coerce')

###Taking the new format out of the dataframe###
df_orig['date'] = df_orig['date'].dt.date

###Saving a new edited CSV and then printing it out to show ###
df_orig.to_csv(os.path.join(log_prefix, "house_file_v2.csv"), index=False)

###Loading from new updated file###
date_time_cleaned = pd.read_csv(os.path.join(log_prefix, "house_file_v2.csv"))

display(HTML("<u>Sample of Cleaned Data:</u>"))
print(date_time_cleaned.head())
# Out:
# <u>Sample of Cleaned Data:</u>
#            id  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520   NaN 221900.00      3.00       1.00      1180.00   5650.00
# 1  6414100192   NaN 538000.00      3.00       2.25      2570.00   7242.00
# 2  5631500400   NaN 180000.00      2.00       1.00       770.00  10000.00
# 3  2487200875   NaN 604000.00      4.00       3.00      1960.00   5000.00
# 4  1954400510   NaN 510000.00      3.00       2.00      1680.00   8080.00
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0    1.00           0     0  ...      7        1180              0      1955
# 1    2.00           0     0  ...      7        2170            400      1951
# 2    1.00           0     0  ...      6         770              0      1933
# 3    1.00           0     0  ...      7        1050            910      1965
# 4    1.00           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode   lat    long  sqft_living15  sqft_lot15
# 0             0    98178 47.51 -122.26           1340        5650
# 1          1991    98125 47.72 -122.32           1690        7639
# 2             0    98028 47.74 -122.23           2720        8062
# 3             0    98136 47.52 -122.39           1360        5000
# 4             0    98074 47.62 -122.05           1800        7503
#
# [5 rows x 21 columns]

# %%
###filtering and saving the data###
date_time_cleaned = date_time_cleaned[(date_time_cleaned['bedrooms'] != 0) & (date_time_cleaned['bathrooms'] != 0)]
date_time_cleaned.to_csv(os.path.join(log_prefix, 'filtered_date_time_cleaned.csv'), index=False)

###Descriptive statistics###
price_description = date_time_cleaned['price'].describe().apply(lambda x: format(round(x, 2), '.2f'))

display(HTML("<u>Price Details:</u>"))
print(price_description)
# Out:
# <u>Price Details:</u>
# count      21598.00
# mean      540200.32
# std       367125.43
# min        78000.00
# 25%       322000.00
# 50%       450000.00
# 75%       645000.00
# max      7700000.00
# Name: price, dtype: object

# %%
###Removing the top and bottom 1% of data in the price column###
working_data = pd.read_csv(os.path.join(log_prefix, 'filtered_date_time_cleaned.csv'))

###Establishing lower and upper bound using the bottom and upper 1%##
upper_bound = working_data['price'].quantile(0.99)
lower_bound = working_data['price'].quantile(0.01)

display(HTML("<u>Defining Bounds to Remove Outliers:</u>"))
print("Upper bound =",round(upper_bound,2))
print("\nLower bound =",round(lower_bound,2))

###Only extracting the data in between the values above the lower bound and values lower than the upper bound###
working_data2 = working_data[(working_data['price'] >= lower_bound) & (working_data['price'] <= upper_bound)]
# Out:
# <u>Defining Bounds to Remove Outliers:</u>
# Upper bound = 1965006.6
#
# Lower bound = 154000.0

# %%
###Print Out summary of changes###
record_start = "Record Start Total:".ljust(25)
num_dropped = "# of Records dropped:".ljust(25)
record_end = "Record End Total:".ljust(25)

print(f"\n{record_start}{df_orig.shape[0]}")
print(f"{num_dropped}{len(df_orig) - len(working_data2)}")
print(f"{record_end}{working_data2.shape[0]}")

###Save copy of file to logs###
working_data2.to_csv(os.path.join(log_prefix, "filtered_price_cleaned.csv"), index=False)

###Describing the new dataframe with lower counts again as well as a new mean of 522,238 instead of the previous ###
### 540,200 ###
working_data2['price'].describe().apply(lambda x: format(round(x, 2), '.2f'))
# Out:
# Record Start Total:      21613
# # of Records dropped:    446
# Record End Total:        21167
# count      21167.00
# mean      522238.23
# std       283392.31
# min       154000.00
# 25%       325000.00
# 50%       450000.00
# 75%       639000.00
# max      1965000.00
# Name: price, dtype: object

# %%
df_clean = pd.read_csv(os.path.join(log_prefix, 'filtered_price_cleaned.csv'))

###Check the range of 'price' to determine bin edges###
display(HTML("<u>Price Details:</u>"))
print(df_clean['price'].describe())

####Create bins for the 'price' with quartiles or a custom range###
price_bins, bin_edges = pd.qcut(df_clean['price'], q=4, labels=False, retbins=True)

df_clean['price_group'] = price_bins

###Display the ranges for each bin & Check the distribution of the groups ###
display(HTML("<u>Bin Ranges:</u>"))
for i in range(len(bin_edges) - 1):
    start, end = bin_edges[i], bin_edges[i + 1]
    print(f"Bin {i + 1} Range: ({start}, {end}]")

# Check the distribution of the groups
display(HTML("<u>Group Distributions:</u>"))
print(df_clean['price_group'].value_counts())


##??date_time_cleaned.to_csv(os.path.join(log_prefix, "filtered_price_cleaned.csv"), index=False)
df.to_csv(os.path.join(log_prefix, 'house_file_v2_grouped.csv'), index=False)
# Out:
# <u>Price Details:</u>
# count     21167.00
# mean     522238.23
# std      283392.31
# min      154000.00
# 25%      325000.00
# 50%      450000.00
# 75%      639000.00
# max     1965000.00
# Name: price, dtype: float64
# <u>Bin Ranges:</u>
# Bin 1 Range: (154000.0, 325000.0]
# Bin 2 Range: (325000.0, 450000.0]
# Bin 3 Range: (450000.0, 639000.0]
# Bin 4 Range: (639000.0, 1965000.0]
# <u>Group Distributions:</u>
# 0    5410
# 3    5284
# 2    5247
# 1    5226
# Name: price_group, dtype: int64

# %%
# Assuming df_clean is your DataFrame
price_bins, bin_edges = pd.qcut(df_clean['price'], q=4, labels=False, retbins=True)

df_clean['price_group'] = price_bins

# Display the ranges for each bin
display(HTML("<u>Bin Ranges:</u>"))
for i, (start, end) in enumerate(zip(bin_edges[:-1], bin_edges[1:])):
    print(f"Bin {i + 1} Range: ({start}, {end}]")

# Check the distribution of the groups
display(HTML("<u>Group Distributions:</u>"))
print(df_clean['price_group'].value_counts())
# Out:
# <u>Bin Ranges:</u>
# Bin 1 Range: (78000.0, 322000.0]
# Bin 2 Range: (322000.0, 450000.0]
# Bin 3 Range: (450000.0, 645000.0]
# Bin 4 Range: (645000.0, 7700000.0]
# <u>Group Distributions:</u>
# 1    5445
# 0    5406
# 2    5376
# 3    5371
# Name: price_group, dtype: int64

# %%
df = pd.read_csv('house_file_v2.csv')

# Create a new column 'price per square foot'
df['price_per_sqft'] = df['price'] / df['sqft_living']

# Normalize the 'price_per_sqft' column
price_per_sqft_mean = df['price_per_sqft'].mean()
price_per_sqft_std = df['price_per_sqft'].std()
df['price_per_sqft_normalized'] = (df['price_per_sqft'] - price_per_sqft_mean) / price_per_sqft_std

# Calculate the average 'price per square foot' for each zipcode
avg_price_per_sqft = df.groupby('zipcode')['price_per_sqft'].mean().reset_index(name='avg_price_per_sqft')
df = pd.merge(df, avg_price_per_sqft, on='zipcode', how='left')

# Convert 'condition' column into categorical data
df['condition'] = df['condition'].astype('category')

# Convert 'yr_built' to age
current_year = 2023
df['age'] = current_year - df['yr_built']

# Change '33' bedrooms to '3'
df.loc[df['bedrooms'] == 33, 'bedrooms'] = 3

# Set display option to show all columns, if needed
pd.set_option('display.max_columns', None)

# Display the first few rows of the DataFrame to check
print(df.head())
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  2014-10-13  221900.0       3.0       1.00       1180.0
# 1  6414100192  2014-12-09  538000.0       3.0       2.25       2570.0
# 2  5631500400  2015-02-25  180000.0       2.0       1.00        770.0
# 3  2487200875  2014-12-09  604000.0       4.0       3.00       1960.0
# 4  1954400510  2015-02-18  510000.0       3.0       2.00       1680.0
#
#    sqft_lot  floors  waterfront  view condition  grade  sqft_above  \
# 0    5650.0     1.0           0     0         3      7        1180
# 1    7242.0     2.0           0     0         3      7        2170
# 2   10000.0     1.0           0     0         3      6         770
# 3    5000.0     1.0           0     0         5      7        1050
# 4    8080.0     1.0           0     0         3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  price_per_sqft  price_per_sqft_normalized  \
# 0           1340        5650      188.050847                  -0.691660
# 1           1690        7639      209.338521                  -0.498488
# 2           2720        8062      233.766234                  -0.276822
# 3           1360        5000      308.163265                   0.398285
# 4           1800        7503      303.571429                   0.356617
#
#    avg_price_per_sqft  age
# 0          189.413607   68
# 1          283.495601   72
# 2          225.095539   90
# 3          337.442238   58
# 4          266.615575   36

# %%
df = pd.read_csv('house_file_v2.csv')

# Removing duplicates
df = df.drop_duplicates()

# drop the columns 'view', 'grade', 'long', and 'lat'
df = df.drop(['view', 'grade', 'long', 'lat'], axis=1)

price_bins = [0, 250000, 500000, 750000, 1000000, df['price'].max()]
price_labels = ['low', 'medium', 'high', 'very high', 'luxury']
df['price_category'] = pd.cut(df['price'], bins=price_bins, labels=price_labels, include_lowest=True)

# Save the transformed DataFrame
df.to_csv('house_file_v2_cleaned.csv', index=False)

# Display the first few rows to verify changes
print(df.head())
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  2014-10-13  221900.0       3.0       1.00       1180.0
# 1  6414100192  2014-12-09  538000.0       3.0       2.25       2570.0
# 2  5631500400  2015-02-25  180000.0       2.0       1.00        770.0
# 3  2487200875  2014-12-09  604000.0       4.0       3.00       1960.0
# 4  1954400510  2015-02-18  510000.0       3.0       2.00       1680.0
#
#    sqft_lot  floors  waterfront  condition  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0          3        1180              0
# 1    7242.0     2.0           0          3        2170            400
# 2   10000.0     1.0           0          3         770              0
# 3    5000.0     1.0           0          5        1050            910
# 4    8080.0     1.0           0          3        1680              0
#
#    yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15 price_category
# 0      1955             0    98178           1340        5650            low
# 1      1951          1991    98125           1690        7639           high
# 2      1933             0    98028           2720        8062            low
# 3      1965             0    98136           1360        5000           high
# 4      1987             0    98074           1800        7503           high

# %%
# Display column names
print(df.columns)

# Check if 'grade' column exists
if 'grade' in df.columns:
    print("'grade' column exists.")
    # Convert it to an ordered categorical type
    grade_order = sorted(df['grade'].unique())
    grade_type = pd.CategoricalDtype(categories=grade_order, ordered=True)
    df['grade'] = df['grade'].astype(grade_type)
else:
    print("'grade' column does not exist. Check for typos or missing data.")

# Set the other columns as per their types
df['waterfront'] = df['waterfront'].astype('category')
df['zipcode'] = df['zipcode'].astype('category')
df['bedrooms'] = pd.to_numeric(df['bedrooms'], errors='coerce')  
df['price'] = pd.to_numeric(df['price'], errors='coerce')  

# Check the data types have been set correctly
print(df.dtypes)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15',
#        'sqft_lot15', 'price_category'],
#       dtype='object')
# 'grade' column does not exist. Check for typos or missing data.
# id                   int64
# date                object
# price              float64
# bedrooms           float64
# bathrooms          float64
# sqft_living        float64
# sqft_lot           float64
# floors             float64
# waterfront        category
# condition            int64
# sqft_above           int64
# sqft_basement        int64
# yr_built             int64
# yr_renovated         int64
# zipcode           category
# sqft_living15        int64
# sqft_lot15           int64
# price_category    category
# dtype: object

# %%
current_directory = os.getcwd()

file_name = 'house_file_v2.csv'
file_path = os.path.join(current_directory, file_name)

try:
    df = pd.read_csv(file_path)
    print("DataFrame loaded successfully.")
except FileNotFoundError:
    print(f"Unable to find the file {file_name} in the directory {current_directory}.")
    
else:
   
 # Visualization of the distribution of 'price'
    plt.figure(figsize=(10, 5))

    # Histogram with a density plot for 'price'
    plt.subplot(1, 2, 1)
    sns.histplot(df['price'], kde=True)
    plt.title('Histogram of House Prices')

    # Boxplot for 'price'
    plt.subplot(1, 2, 2)
    sns.boxplot(y=df['price'])
    plt.title('Boxplot of House Prices')
    plt.tight_layout()
    plt.show()

    numerical_df = df.select_dtypes(include=['float64', 'int64'])

    # Correlation matrix heatmap using only numerical columns
    plt.figure(figsize=(12, 10))
    corr_matrix = numerical_df.corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix of Numerical Variables')
    plt.show()
# Out:
# DataFrame loaded successfully.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Read in your data file
df = pd.read_csv('house_sales.csv')  # Ensure the file name is correct

df = df.apply(pd.to_numeric, errors='coerce')

# NaN values with the mean of each column
df.fillna(df.mean(), inplace=True)

# Correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print(correlation_matrix)

# Set the figure size for the heatmap
plt.figure(figsize=(10, 8))

# Create the heatmap with annotations and a chosen color map
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')

# Show the plot
plt.show()
# Out:
#                      id  date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000   NaN -0.016762  0.003388   0.002042    -0.011431
# date                NaN   NaN       NaN       NaN        NaN          NaN
# price         -0.016762   NaN  1.000000  0.303430   0.515786     0.681806
# bedrooms       0.003388   NaN  0.303430  1.000000   0.489916     0.550486
# bathrooms      0.002042   NaN  0.515786  0.489916   1.000000     0.715240
# sqft_living   -0.011431   NaN  0.681806  0.550486   0.715240     1.000000
# sqft_lot      -0.129849   NaN  0.086295  0.027305   0.083331     0.160199
# floors         0.018525   NaN  0.256794  0.173207   0.487949     0.345740
# waterfront    -0.002721   NaN  0.266369 -0.004307   0.067560     0.105058
# view           0.011592   NaN  0.397293  0.080248   0.181404     0.276703
# condition     -0.023783   NaN  0.036362  0.027456  -0.122835    -0.057778
# grade          0.008130   NaN  0.667434  0.349893   0.648845     0.744523
# sqft_above    -0.010842   NaN  0.605567  0.466705   0.668182     0.851347
# sqft_basement -0.005151   NaN  0.323816  0.293539   0.277249     0.420815
# yr_built       0.021380   NaN  0.054012  0.152156   0.495377     0.311365
# yr_renovated  -0.016907   NaN  0.126434  0.019447   0.048745     0.055698
# zipcode       -0.008224   NaN -0.053203 -0.150046  -0.200678    -0.194479
# lat           -0.001891   NaN  0.307003 -0.009004   0.026717     0.049772
# long           0.020799   NaN  0.021626  0.127045   0.218228     0.233190
# sqft_living15 -0.002901   NaN  0.585379  0.382599   0.554886     0.737337
# sqft_lot15    -0.138798   NaN  0.082447  0.024606   0.086581     0.175682
#
#                sqft_lot    floors  waterfront      view  ...     grade  \
# id            -0.129849  0.018525   -0.002721  0.011592  ...  0.008130
# date                NaN       NaN         NaN       NaN  ...       NaN
# price          0.086295  0.256794    0.266369  0.397293  ...  0.667434
# bedrooms       0.027305  0.173207   -0.004307  0.080248  ...  0.349893
# bathrooms      0.083331  0.487949    0.067560  0.181404  ...  0.648845
# sqft_living    0.160199  0.345740    0.105058  0.276703  ...  0.744523
# sqft_lot       1.000000 -0.005540    0.020712  0.072944  ...  0.109002
# floors        -0.005540  1.000000    0.023698  0.029444  ...  0.458183
# waterfront     0.020712  0.023698    1.000000  0.401857  ...  0.082775
# view           0.072944  0.029444    0.401857  1.000000  ...  0.251321
# condition     -0.008930 -0.263768    0.016653  0.045990  ... -0.144674
# grade          0.109002  0.458183    0.082775  0.251321  ...  1.000000
# sqft_above     0.176906  0.523885    0.072075  0.167649  ...  0.755923
# sqft_basement  0.015212 -0.245705    0.080588  0.276947  ...  0.168392
# yr_built       0.050872  0.489319   -0.026161 -0.053440  ...  0.446963
# yr_renovated   0.008758  0.006338    0.092885  0.103917  ...  0.014414
# zipcode       -0.128141 -0.059121    0.030285  0.084827  ... -0.184862
# lat           -0.085408  0.049614   -0.014274  0.006157  ...  0.114084
# long           0.223964  0.125419   -0.041910 -0.078400  ...  0.198372
# sqft_living15  0.141840  0.279885    0.086463  0.280439  ...  0.713202
# sqft_lot15     0.717743 -0.011269    0.030703  0.072575  ...  0.119248
#
#                sqft_above  sqft_basement  yr_built  yr_renovated   zipcode  \
# id              -0.010842      -0.005151  0.021380     -0.016907 -0.008224
# date                  NaN            NaN       NaN           NaN       NaN
# price            0.605567       0.323816  0.054012      0.126434 -0.053203
# bedrooms         0.466705       0.293539  0.152156      0.019447 -0.150046
# bathrooms        0.668182       0.277249  0.495377      0.048745 -0.200678
# sqft_living      0.851347       0.420815  0.311365      0.055698 -0.194479
# sqft_lot         0.176906       0.015212  0.050872      0.008758 -0.128141
# floors           0.523885      -0.245705  0.489319      0.006338 -0.059121
# waterfront       0.072075       0.080588 -0.026161      0.092885  0.030285
# view             0.167649       0.276947 -0.053440      0.103917  0.084827
# condition       -0.158214       0.174105 -0.361417     -0.060618  0.003026
# grade            0.755923       0.168392  0.446963      0.014414 -0.184862
# sqft_above       1.000000      -0.051943  0.423898      0.023285 -0.261190
# sqft_basement   -0.051943       1.000000 -0.133124      0.071323  0.074845
# yr_built         0.423898      -0.133124  1.000000     -0.224874 -0.346869
# yr_renovated     0.023285       0.071323 -0.224874      1.000000  0.064357
# zipcode         -0.261190       0.074845 -0.346869      0.064357  1.000000
# lat             -0.000816       0.110538 -0.148122      0.029398  0.267048
# long             0.343803      -0.144765  0.409356     -0.068372 -0.564072
# sqft_living15    0.731870       0.200355  0.326229     -0.002673 -0.279033
# sqft_lot15       0.194050       0.017276  0.070958      0.007854 -0.147221
#
#                     lat      long  sqft_living15  sqft_lot15
# id            -0.001891  0.020799      -0.002901   -0.138798
# date                NaN       NaN            NaN         NaN
# price          0.307003  0.021626       0.585379    0.082447
# bedrooms      -0.009004  0.127045       0.382599    0.024606
# bathrooms      0.026717  0.218228       0.554886    0.086581
# sqft_living    0.049772  0.233190       0.737337    0.175682
# sqft_lot      -0.085408  0.223964       0.141840    0.717743
# floors         0.049614  0.125419       0.279885   -0.011269
# waterfront    -0.014274 -0.041910       0.086463    0.030703
# view           0.006157 -0.078400       0.280439    0.072575
# condition     -0.014941 -0.106500      -0.092824   -0.003406
# grade          0.114084  0.198372       0.713202    0.119248
# sqft_above    -0.000816  0.343803       0.731870    0.194050
# sqft_basement  0.110538 -0.144765       0.200355    0.017276
# yr_built      -0.148122  0.409356       0.326229    0.070958
# yr_renovated   0.029398 -0.068372      -0.002673    0.007854
# zipcode        0.267048 -0.564072      -0.279033   -0.147221
# lat            1.000000 -0.135512       0.048858   -0.086419
# long          -0.135512  1.000000       0.334605    0.254451
# sqft_living15  0.048858  0.334605       1.000000    0.183192
# sqft_lot15    -0.086419  0.254451       0.183192    1.000000
#
# [21 rows x 21 columns]
